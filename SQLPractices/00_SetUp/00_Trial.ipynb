# %% [markdown]
# ## Introduction
# A recall of how to use SQL in Jupyter Notebook
#
# ### Sources and References
# 1. IBM Courses on Data Science
# 2. VS Code Jupyter Notebooks Documentation

# %% [markdown]
# ## Some ways to use SQL in Jupyter Notebook
# - Using SQL Magic Commands
# - Using Python Data Base Libraries (sqllite and pandas)

# %% [markdown]
# ### Using SQL Magic Commands

# %% [markdown]
# #### 1. Install necessary packages

# %%
# This bash script sets up a Python environment for working with SQL databases.
# %pip install jupyter ipython-sql

# %% [markdown]
# #### 2. Load and connect database

# %%
# Load the SQL extension
# %load_ext sql

# Connect to a database (SQLite example)
# %sql sqlite:///mydatabase.db

# %% [markdown]
# ### Using Python Data Base Libraries (SQLlite and Pandas)

# %%
import sqlite3
import pandas as pd

# Connect to database
conn = sqlite3.connect('mydatabase.db')

# Read SQL directly into pandas
df = pd.read_sql_query("SELECT * FROM table_name", conn)

# Or use cursor
cursor = conn.cursor()
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()
