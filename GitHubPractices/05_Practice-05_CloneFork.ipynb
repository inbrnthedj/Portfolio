# %% [markdown]
# ## Description
# This is a Jupyter Notebook documentation of my git practice (describe)
# - **Argument**: Cloning and Forking
# - **Source**: Getting Started with Git Github course by IBM on Coursera
# - **Date**: 28/12/2025

# %% [markdown]
# ## Process
#
# Here are my codes and description
#
# 1. **Fork Existing repository using UI**
#     - description of the command
# ```bash
#
# ```
#
# 2. **Clone forked repository in the lab environment**
#     - description of the command
#
# 3. **Create a new branch**
#     - description of the command
#
# 4. **Make changes locally**
#     - description of the command
#
# 5. **Add and commit to local branch**
#     - description of the command
#
# 6. **Push changes to forked repository**
#     - description of the command
#
# 7. **Create pull request to the upstream repository**
#     - description of the command

# %% [markdown]
# ### Other Notes
# Here are some Git commands that are related to the ones used above:
# - **git command** : description
# - **git command** : description
# - **git command** : description
